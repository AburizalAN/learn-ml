# %% [markdown]
# **Instructions for Students:**
#
# Please carefully follow these steps to complete and submit your project:
#
# 1. **Completing the Project**: You are required to work on and complete all tasks in the provided project. Be disciplined and ensure that you thoroughly engage with each task.
# 2. **Set up a Google Drive Folder**: Each of you must store your work in folder on your Google Drive. Create a new folder if you haven't already. This will be the repository for all your completed project files, aiding you in keeping your work organized and accessible.
# 3. **Uploading Completed Project**: Upon completion of your project, make sure to upload all necessary files, involving codes, reports, and related documents into the Google Drive folder. Save this link in the 'Student Identity' section and also provide it as the last parameter in the `submit` function that has been provided.
# 4. **Sharing Folder Link**: You're required to share the link to your project Google Drive folder. This is crucial for the submission and evaluation of your project.
# 5. **Setting Permission toPublic**: Please make sure your Google Drive folder is set to public. This allows your instructor to access your solutions and assess your work correctly.
#
# Adhering to these procedures will facilitate a smooth project process for you and the reviewers.

# %% [markdown]
# ## Student Identity

# %%
# @title #### Student Identity
student_id = "REAEAYH8" # @param {type:"string"}
name = "Aburizal Adi Nugroho" # @param {type:"string"}
drive_link = "https://drive.google.com/drive/folders/1pRIbA2Zphrtg_TS5N0ypHHTXkUBs50tI?usp=sharing"  # @param {type:"string"}

# %% [markdown]
# ## Import package

# %%
# !pip install fastbook

# !pip install rggrader
from rggrader import submit
# Out:
# Collecting fastbook
#   Using cached fastbook-0.0.29-py3-none-any.whl (719 kB)
# Requirement already satisfied: pip in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastbook) (23.3.2)
# Requirement already satisfied: packaging in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastbook) (23.2)
# Collecting fastai>=2.6 (from fastbook)
#   Using cached fastai-2.7.13-py3-none-any.whl.metadata (9.6 kB)
# Collecting graphviz (from fastbook)
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: pandas in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastbook) (2.1.4)
# Requirement already satisfied: requests in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastbook) (2.31.0)
# Collecting transformers (from fastbook)
#   Using cached transformers-4.37.1-py3-none-any.whl.metadata (129 kB)
# Collecting datasets (from fastbook)
#   Using cached datasets-2.16.1-py3-none-any.whl.metadata (20 kB)
# Collecting ipywidgets<8 (from fastbook)
#   Using cached ipywidgets-7.8.1-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting sentencepiece (from fastbook)
#   Downloading sentencepiece-0.1.99-cp311-cp311-win_amd64.whl (977 kB)
#      ---------------------------------------- 0.0/977.5 kB ? eta -:--:--
#      ---------------------------------------- 10.2/977.5 kB ? eta -:--:--
#      - ----------------------------------- 41.0/977.5 kB 487.6 kB/s eta 0:00:02
#      ---- ------------------------------- 112.6/977.5 kB 930.9 kB/s eta 0:00:01
#      --------- ---------------------------- 256.0/977.5 kB 1.6 MB/s eta 0:00:01
#      ------------- ------------------------ 337.9/977.5 kB 1.6 MB/s eta 0:00:01
#      ------------- ------------------------ 358.4/977.5 kB 1.5 MB/s eta 0:00:01
#      ----------------- -------------------- 440.3/977.5 kB 1.6 MB/s eta 0:00:01
#      -------------------- ----------------- 532.5/977.5 kB 1.5 MB/s eta 0:00:01
#      ----------------------- -------------- 614.4/977.5 kB 1.6 MB/s eta 0:00:01
#      --------------------------- ---------- 706.6/977.5 kB 1.7 MB/s eta 0:00:01
#      ------------------------------- ------ 809.0/977.5 kB 1.7 MB/s eta 0:00:01
#      ----------------------------------- -- 901.1/977.5 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 977.5/977.5 kB 1.7 MB/s eta 0:00:00
# Collecting fastdownload<2,>=0.0.5 (from fastai>=2.6->fastbook)
#   Downloading fastdownload-0.0.7-py3-none-any.whl (12 kB)
# Collecting fastcore<1.6,>=1.5.29 (from fastai>=2.6->fastbook)
#   Downloading fastcore-1.5.29-py3-none-any.whl (67 kB)
#      ---------------------------------------- 0.0/67.6 kB ? eta -:--:--
#      ------------------------------------ --- 61.4/67.6 kB ? eta -:--:--
#      -------------------------------------- 67.6/67.6 kB 735.3 kB/s eta 0:00:00
# Requirement already satisfied: torchvision>=0.11 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastai>=2.6->fastbook) (0.16.2+cu118)
# Requirement already satisfied: matplotlib in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastai>=2.6->fastbook) (3.8.2)
# Requirement already satisfied: pyyaml in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastai>=2.6->fastbook) (6.0.1)
# Collecting fastprogress>=0.2.4 (from fastai>=2.6->fastbook)
#   Downloading fastprogress-1.0.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastai>=2.6->fastbook) (10.1.0)
# Requirement already satisfied: scikit-learn in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastai>=2.6->fastbook) (1.4.0)
# Requirement already satisfied: scipy in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastai>=2.6->fastbook) (1.11.4)
# Collecting spacy<4 (from fastai>=2.6->fastbook)
#   Downloading spacy-3.7.2-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: torch<2.2,>=1.10 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from fastai>=2.6->fastbook) (2.1.2+cu118)
# Requirement already satisfied: comm>=0.1.3 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipywidgets<8->fastbook) (0.2.0)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets<8->fastbook)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipywidgets<8->fastbook) (5.14.0)
# Collecting widgetsnbextension~=3.6.6 (from ipywidgets<8->fastbook)
#   Downloading widgetsnbextension-3.6.6-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipywidgets<8->fastbook) (8.19.0)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets<8->fastbook)
#   Downloading jupyterlab_widgets-1.1.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: filelock in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from datasets->fastbook) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from datasets->fastbook) (1.26.2)
# Collecting pyarrow>=8.0.0 (from datasets->fastbook)
#   Downloading pyarrow-15.0.0-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting pyarrow-hotfix (from datasets->fastbook)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->fastbook)
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from datasets->fastbook) (4.66.1)
# Collecting xxhash (from datasets->fastbook)
#   Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->fastbook)
#   Downloading multiprocess-0.70.15-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2023.10.0,>=2023.1.0 (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets->fastbook)
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting aiohttp (from datasets->fastbook)
#   Downloading aiohttp-3.9.1-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from datasets->fastbook) (0.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from requests->fastbook) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from requests->fastbook) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from requests->fastbook) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from requests->fastbook) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pandas->fastbook) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pandas->fastbook) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pandas->fastbook) (2023.3)
# Collecting regex!=2019.12.17 (from transformers->fastbook)
#   Downloading regex-2023.12.25-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ----------------------------- ---------- 30.7/42.0 kB ? eta -:--:--
#      -------------------------------------- 42.0/42.0 kB 406.8 kB/s eta 0:00:00
# Collecting tokenizers<0.19,>=0.14 (from transformers->fastbook)
#   Downloading tokenizers-0.15.1-cp311-none-win_amd64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.3.1 (from transformers->fastbook)
#   Downloading safetensors-0.4.2-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from aiohttp->datasets->fastbook) (23.2.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->fastbook)
#   Downloading multidict-6.0.4-cp311-cp311-win_amd64.whl (28 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->fastbook)
#   Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->fastbook)
#   Downloading frozenlist-1.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->fastbook)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from huggingface-hub>=0.19.4->datasets->fastbook) (4.9.0)
# Requirement already satisfied: decorator in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (2.17.2)
# Requirement already satisfied: stack-data in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.6.3)
# Requirement already satisfied: colorama in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipython>=4.0.0->ipywidgets<8->fastbook) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from python-dateutil>=2.8.2->pandas->fastbook) (1.16.0)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading murmurhash-1.0.10-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading cymem-2.0.8-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading preshed-3.0.9-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading thinc-8.2.2-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading srsly-2.4.8-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (0.9.0)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (2.5.3)
# Requirement already satisfied: jinja2 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from spacy<4->fastai>=2.6->fastbook) (65.5.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy<4->fastai>=2.6->fastbook)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ---------------------------------------- 0.0/181.6 kB ? eta -:--:--
#      -------- ---------------------------- 41.0/181.6 kB 991.0 kB/s eta 0:00:01
#      -------- ---------------------------- 41.0/181.6 kB 991.0 kB/s eta 0:00:01
#      -------- ---------------------------- 41.0/181.6 kB 991.0 kB/s eta 0:00:01
#      -------- ---------------------------- 41.0/181.6 kB 991.0 kB/s eta 0:00:01
#      -------- ---------------------------- 41.0/181.6 kB 991.0 kB/s eta 0:00:01
#      ------------------ ------------------ 92.2/181.6 kB 348.6 kB/s eta 0:00:01
#      ------------------ ------------------ 92.2/181.6 kB 348.6 kB/s eta 0:00:01
#      ------------------ ------------------ 92.2/181.6 kB 348.6 kB/s eta 0:00:01
#      ------------------ ------------------ 92.2/181.6 kB 348.6 kB/s eta 0:00:01
#      -------------------------------- --- 163.8/181.6 kB 339.1 kB/s eta 0:00:01
#      -------------------------------- --- 163.8/181.6 kB 339.1 kB/s eta 0:00:01
#      -------------------------------- --- 163.8/181.6 kB 339.1 kB/s eta 0:00:01
#      -------------------------------- --- 163.8/181.6 kB 339.1 kB/s eta 0:00:01
#      ---------------------------------- - 174.1/181.6 kB 255.6 kB/s eta 0:00:01
#      ---------------------------------- - 174.1/181.6 kB 255.6 kB/s eta 0:00:01
#      ---------------------------------- - 174.1/181.6 kB 255.6 kB/s eta 0:00:01
#      ------------------------------------ 181.6/181.6 kB 228.5 kB/s eta 0:00:00
# Requirement already satisfied: sympy in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (1.12)
# Requirement already satisfied: networkx in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from torch<2.2,>=1.10->fastai>=2.6->fastbook) (3.2.1)
# Collecting notebook>=4.4.1 (from widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading notebook-7.0.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from matplotlib->fastai>=2.6->fastbook) (3.1.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from scikit-learn->fastai>=2.6->fastbook) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from scikit-learn->fastai>=2.6->fastbook) (3.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8->fastbook) (0.8.3)
# Collecting jupyter-server<3,>=2.4.0 (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading jupyter_server-2.12.5-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.22.1 (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading jupyterlab_server-2.25.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<5,>=4.0.2 (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading jupyterlab-4.0.11-py3-none-any.whl.metadata (15 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (6.4)
# Requirement already satisfied: wcwidth in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.12)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.6->fastbook) (2.14.6)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy<4->fastai>=2.6->fastbook)
#   Downloading blis-0.7.11-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy<4->fastai>=2.6->fastbook)
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai>=2.6->fastbook) (8.1.7)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy<4->fastai>=2.6->fastbook)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jinja2->spacy<4->fastai>=2.6->fastbook) (2.1.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8->fastbook) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from sympy->torch<2.2,>=1.10->fastai>=2.6->fastbook) (1.3.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.2.0)
# Collecting argon2-cffi (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (5.5.1)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading jupyter_events-0.9.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jupyter-server-terminals (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading jupyter_server_terminals-0.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading nbconvert-7.14.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting overrides (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading overrides-7.6.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading prometheus_client-0.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading pywinpty-2.0.12-cp311-none-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pyzmq>=24 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (25.1.2)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading terminado-0.18.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading websocket_client-1.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: ipykernel in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (6.27.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading jupyter_lsp-2.2.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading Babel-2.14.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading json5-0.9.14-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.20.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (0.16.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (4.1.0)
# Requirement already satisfied: pywin32>=300 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (306)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting beautifulsoup4 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading nbclient-0.9.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting fastjsonschema (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.8.0)
# Requirement already satisfied: nest-asyncio in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (1.5.8)
# Requirement already satisfied: psutil in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook) (5.9.7)
# Collecting webencodings (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl.metadata (1.5 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<8->fastbook)
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0
MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.6/11.0 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.8/11.0 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.8/11.0 MB 2.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.8/11.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.0 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.3/11.0 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.0 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  10.9/11.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 2.4 MB/s eta 0:00:00
# Downloading json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Downloading jupyter_events-0.9.0-py3-none-any.whl (18 kB)
# Downloading jupyter_lsp-2.2.2-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.8 kB ? eta -:--:--
#    ----------------------------------- ---- 61.4/68.8 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 68.8/68.8 kB 1.3 MB/s eta 0:00:00
# Downloading nbconvert-7.14.2-py3-none-any.whl (256 kB)
#    ---------------------------------------- 0.0/256.4 kB ? eta -:--:--
#    ------------------------------- -------- 204.8/256.4 kB 6.3 MB/s eta 0:00:01
#    ------------------------------------ --- 235.5/256.4 kB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 256.4/256.4 kB 2.0 MB/s eta 0:00:00
# Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    ------------------------------- -------- 61.4/77.6 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 77.6/77.6 kB 863.4 kB/s eta 0:00:00
# Downloading terminado-0.18.0-py3-none-any.whl (14 kB)
# Downloading pywinpty-2.0.12-cp311-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------ --------------------------------- 0.2/1.4 MB 6.7 MB/s eta 0:00:01
#    -------- ------------------------------- 0.3/1.4 MB 4.9 MB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.4 MB 4.3 MB/s eta 0:00:01
#    -------------------- ------------------- 0.7/1.4 MB 4.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.4 MB 4.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.4 MB 4.1 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 3.1 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 3.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.4 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 1.1/1.4 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.4 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.4 MB/s eta 0:00:00
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading jupyter_server_terminals-0.5.2-py3-none-any.whl (13 kB)
# Downloading overrides-7.6.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.19.0-py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.2 kB ? eta -:--:--
#    ------------------------------------- -- 51.2/54.2 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 54.2/54.2 kB 935.9 kB/s eta 0:00:00
# Downloading websocket_client-1.7.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.5 kB ? eta -:--:--
#    ---------------------------- ----------- 41.0/58.5 kB ? eta -:--:--
#    ---------------------------------------- 58.5/58.5 kB 1.6 MB/s eta 0:00:00
# Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#    ----------------------------------- ---- 143.4/162.8 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 162.8/162.8 kB 2.4 MB/s eta 0:00:00
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/48.0 kB ? eta -:--:--
#    ---------------------------------- ----- 41.0/48.0 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 48.0/48.0 kB 802.5 kB/s eta 0:00:00
# Downloading nbclient-0.9.0-py3-none-any.whl (24 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    --------------------------------- ------ 122.9/147.9 kB ? eta -:--:--
#    --------------------------------- ------ 122.9/147.9 kB ? eta -:--:--
#    ---------------------------------------- 147.9/147.9 kB 1.5 MB/s eta 0:00:00
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading cffi-1.16.0-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.5 kB ? eta -:--:--
#    -------------------------------------- - 174.1/181.5 kB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 174.1/181.5 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 181.5/181.5 kB 1.8 MB/s eta 0:00:00
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.4 kB ? eta -:--:--
#    ------------------------------------- -- 61.4/66.4 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 66.4/66.4 kB 604.1 kB/s eta 0:00:00
# Downloading types_python_dateutil-2.8.19.20240106-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, sentencepiece, json5, ipython-genutils, fastjsonschema, cymem, xxhash, websocket-client, webcolors, wasabi, uri-template, types-python-dateutil, tinycss2, spacy-loggers, spacy-legacy, soupsieve, smart-open, send2trash, safetensors, rfc3986-validator, rfc3339-validator, regex, pywinpty, python-json-logger, pycparser, pyarrow-hotfix, pyarrow, prometheus-client, pandocfilters, overrides, murmurhash, multidict, mistune, langcodes, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, graphviz, fsspec, frozenlist, fqdn, fastprogress, fastcore, dill, defusedxml, cloudpathlib, catalogue, blis, bleach, babel, async-lru, yarl, terminado, srsly, preshed, multiprocess, fastdownload, cffi, beautifulsoup4, arrow, aiosignal, tokenizers, jupyter-server-terminals, isoduration, confection, argon2-cffi-bindings, aiohttp, weasel, transformers, thinc, nbformat, argon2-cffi, spacy, nbclient, jupyter-events, datasets, nbconvert, fastai, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, widgetsnbextension, ipywidgets, fastbook
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.12.2
#     Uninstalling fsspec-2023.12.2:
#       Successfully uninstalled fsspec-2023.12.2
# Successfully installed aiohttp-3.9.1 aiosignal-1.3.1 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 babel-2.14.0 beautifulsoup4-4.12.3 bleach-6.1.0 blis-0.7.11 catalogue-2.0.10 cffi-1.16.0 cloudpathlib-0.16.0 confection-0.1.4 cymem-2.0.8 datasets-2.16.1 defusedxml-0.7.1 dill-0.3.7 fastai-2.7.13 fastbook-0.0.29 fastcore-1.5.29 fastdownload-0.0.7 fastjsonschema-2.19.1 fastprogress-1.0.3 fqdn-1.5.1 frozenlist-1.4.1 fsspec-2023.10.0 graphviz-0.20.1 ipython-genutils-0.2.0 ipywidgets-7.8.1 isoduration-20.11.0 json5-0.9.14 jsonpointer-2.4 jupyter-events-0.9.0 jupyter-lsp-2.2.2 jupyter-server-2.12.5 jupyter-server-terminals-0.5.2 jupyterlab-4.0.11 jupyterlab-pygments-0.3.0 jupyterlab-server-2.25.2 jupyterlab-widgets-1.1.7 langcodes-3.3.0 mistune-3.0.2 multidict-6.0.4 multiprocess-0.70.15 murmurhash-1.0.10 nbclient-0.9.0 nbconvert-7.14.2 nbformat-5.9.2 notebook-7.0.7 notebook-shim-0.2.3 overrides-7.6.0 pandocfilters-1.5.1 preshed-3.0.9 prometheus-client-0.19.0 pyarrow-15.0.0 pyarrow-hotfix-0.6 pycparser-2.21 python-json-logger-2.0.7 pywinpty-2.0.12 regex-2023.12.25 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 safetensors-0.4.2 send2trash-1.8.2 sentencepiece-0.1.99 smart-open-6.4.0 soupsieve-2.5 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 terminado-0.18.0 thinc-8.2.2 tinycss2-1.2.1 tokenizers-0.15.1 transformers-4.37.1 types-python-dateutil-2.8.19.20240106 uri-template-1.3.0 wasabi-1.1.2 weasel-0.3.4 webcolors-1.13 webencodings-0.5.1 websocket-client-1.7.0 widgetsnbextension-3.6.6 xxhash-3.4.1 yarl-1.9.4
# Collecting rggrader
#   Using cached rggrader-0.1.6-py3-none-any.whl.metadata (485 bytes)
# Requirement already satisfied: requests in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from rggrader) (2.31.0)
# Requirement already satisfied: pandas in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from rggrader) (2.1.4)
# Requirement already satisfied: Pillow in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from rggrader) (10.1.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pandas->rggrader) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pandas->rggrader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pandas->rggrader) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from pandas->rggrader) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from requests->rggrader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from requests->rggrader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from requests->rggrader) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from requests->rggrader) (2023.11.17)
# Requirement already satisfied: six>=1.5 in c:\users\aburi\documents\aburizalan\learn-ml\myvenv-311\lib\site-packages (from python-dateutil>=2.8.2->pandas->rggrader) (1.16.0)
# Using cached rggrader-0.1.6-py3-none-any.whl (2.5 kB)
# Installing collected packages: rggrader
# Successfully installed rggrader-0.1.6

# %% [markdown]
# ## Task 1
#
# Given
#
# $$
# X = \begin{bmatrix}
# a \\
# b \\
# c \\
# d \\
# e
# \end{bmatrix}
# $$
#
# and
#
# $$
# M =
# \begin{bmatrix}
# -2 & 3 & 3 & 3 & -4 \\
# 0 & -4 & -1 & 1 & 2 \\
# 1 & 5 & 4 & 2 & 0 \\
# -2 & 5 & -5 & 3 & 1 \\
# -3 & 2 & 4 & 3 & 4 \\
# \end{bmatrix}
# $$
#
# and
#
# $$
# M \cdot X =
#  =
# \begin{bmatrix}
# -33 \\
# 9 \\
# -34 \\
# -38 \\
#  -40
# \end{bmatrix}
# $$
#
# What is the value of $a + b + c + d + e$?

# %%
# You may add any code here to derive your variables
# Please change this
import torch

mx = torch.tensor([-33, 9, -34, -38, -40], dtype=torch.float64)
m = torch.tensor([[-2, 3, 3, 3, -4],
                  [0, -4, -1, 1, 2],
                  [1, 5, 4, 2, 0],
                  [-2, 5, -5, 3, 1],
                  [-3, 2, 4, 3, 4]], dtype=torch.float64)

if torch.det(m) != 0:
  m_inverse = torch.inverse(m)
  x = m_inverse @ mx

  total = torch.sum(x, dim=None)

  assignment_id = "09-deep-learning-project"
  question_id = "q1_linear_algebra"
  submit(student_id, name, assignment_id, str(total), question_id, drive_link)

# %% [markdown]
# ## Task 2
#
# What is the output of the following Neural Network?

# %%
from fastbook import *


# Draw neurons with multiple inputs and weights
gv('''
z_1[shape=box3d width=1 height=0.7 label="b = -2, ReLU"];
z_2[shape=box3d width=1 height=0.7 label="b = -6, ReLU"];
z_3[shape=box3d width=1 height=0.7 label="b = 4, ReLU"];
input_1[width=1 height=0.7 label="4"];
input_2[width=1 height=0.7 label="-3"];
input_1 -> z_1 [label="4"]
input_2 -> z_1 [label="2"]
input_1 -> z_2 [label="0"]
input_2 -> z_2 [label="-1"]

z_1 -> z_3 [label="2"]
z_2 -> z_3 [label="3"]
z_3 ->output


''')

# %%
# You may add any code here to derive your variables
# Please change this

x = torch.tensor([[4], [-3]])
w_0 = torch.tensor([[4, 2], [0, -1]])
b_0 = torch.tensor([[-2], [-6]])
a_0 = torch.relu(w_0 @ x + b_0)

w_1 = torch.tensor([[2, 3]])
b_1 = torch.tensor([[4]])
a_1 = torch.relu(w_1 @ a_0 + b_1)

output = a_1.item()

print(f"The output is {output}")

assignment_id = "09-deep-learning-project"
question_id = "q2_simple_neural_network"
submit(student_id, name, assignment_id, str(output), question_id, drive_link)
# Out:
# The output is tensor([[20]])
# 'Assignment successfully submitted'

# %% [markdown]
# ## Task 3
#
# Given the following Neural Networks:
#
# First layer:
#
# $$
# W = \begin{bmatrix}
# 0.23 & 0.67 & 0.12 \\
# -0.89 & -0.45 & 0.78 \\
# 0.34 & 0.56 & -0.90 \\
# -0.12 & 0.34 & 0.56 \\
# 0.78 & -0.90 & 0.23 \\
# \end{bmatrix}
# $$
#
# $$
# bias = \begin{bmatrix}
# 0.23 \\
# -0.89 \\
# 0.34 \\
# 0.12 \\
# -0.78 \\
# \end{bmatrix}
# $$
#
# Second layer:
#
# $$
# W = \begin{bmatrix}
# 0.23 & 0.67 & 0.12 & 0.45 & 0.89 \\
# 0.12 & 0.34 & 0.56 & 0.78 & 0.90 \\
# \end{bmatrix}
# $$
#
# $$
# bias = \begin{bmatrix}
# 1.96 \\
# -1.08 \\
# \end{bmatrix}
# $$
#
# Third layer:
#
# $$
# W = \begin{bmatrix}
# 1.08 & -0.16
# \end{bmatrix}
# $$
#
# $$
# bias = \begin{bmatrix}
# -2.8
# \end{bmatrix}
# $$
#
# All layers use the ReLU activation function.
#
# What is the output given the following inputs?
#
# $$
# X = \begin{bmatrix}
# 1 \\
# 2 \\
# 4 \\
# \end{bmatrix}
#
#
# $$

# %%
# You may add any code here to derive your variables
import torch

x = torch.tensor([[1], [2], [4]], dtype=torch.float64)
w_0 = torch.tensor([[0.23, 0.67, 0.12], 
                   [0.89, 0.45, 0.78],
                   [0.23, 0.67, 0.12],
                   [0.23, 0.67, 0.12],
                   [0.23, 0.67, 0.12]], dtype=torch.float64)
b_0 = torch.tensor([[0.23], [-0.89], [0.34], [0.12], [-0.78]], dtype=torch.float64)
a_0 = torch.relu(w_0 @ x + b_0)

print("a_0")
print(a_0.shape)

w_1 = torch.tensor([[0.23, 0.67, 0.12, 0.45, 0.89],
                    [0.12, 0.34, 0.56, 0.78, 0.90]], dtype=torch.float64)
b_1 = torch.tensor([[1.96], [-1.08]], dtype=torch.float64)
a_1 = torch.relu(w_1 @ a_0 + b_1)

print(a_1)

w_2 = torch.tensor([1.08, -0.16], dtype=torch.float64)
b_2 = torch.tensor([-2.8])
a_2 = torch.relu(w_2 @ a_1 + b_2)

# Please change this
output = a_2.item()

print(f"The output is {output}")

# assignment_id = "09-deep-learning-project"
# question_id = "q3_complex_neural_network"
# submit(student_id, name, assignment_id, str(output), question_id, drive_link)
# Out:
# a_0
# torch.Size([5, 1])
# tensor([[5.6552],
#         [3.7620]], dtype=torch.float64)
# The output is 2.705696047683716

# %% [markdown]
# ## Task 4
#
# Given [the following sheet (sheet name = Project A)](https://docs.google.com/spreadsheets/d/15JWbRFB4k5CNcfD-2hduHHssXIc1SGhNVSpu_30wVAw/edit#gid=180755192)
#
# Make a backpropagation algorithm to train the network. You can refer to AND and NOT sheet. Use sigmoid activation function for all
#
# Hint: it needs 1 layer with 1 neuron
#
# What is the cost at 10th iteration (the iteration start from 1)?

# %%
# Please clone the Google Sheet and do your calculation there

# Please change this
cost = 0

# Don't forget to fill in the link to your Google Sheet
link_to_gsheet = ""

print(f"The cost is {cost}")

assignment_id = "09-deep-learning-project"

question_id = "q4_cost_function_cost"
submit(student_id, name, assignment_id, str(cost), question_id)

question_id = "q4_cost_function_gsheet"
submit(student_id, name, assignment_id, str(link_to_gsheet), question_id, drive_link)

# %% [markdown]
# ## Task 5 (BONUS - OPTIONAL)
#
# _This task is optional, it will earn you a distinction, but will not give you additional points._
#
# Given [the following sheet (sheet name = Project B)](https://docs.google.com/spreadsheets/d/15JWbRFB4k5CNcfD-2hduHHssXIc1SGhNVSpu_30wVAw/edit#gid=1029811725)
#
# Make a backpropagation algorithm to train the network. You can refer to AND and NOT sheet. Use sigmoid activation function for all
#
# Hint: it needs 2 layer (1 hidden layer + 1 output layer). The hidden layer has 2 neurons
#
# What is the cost at 10th iteration (the iteration start from 1)?

# %%
# Please clone the Google Sheet and do your calculation there

# Please change this
cost = 0

# Don't forget to fill in the link to your Google Sheet
link_to_gsheet = ""

print(f"The cost is {cost}")

assignment_id = "09-deep-learning-project"

question_id = "q5_cost_function_cost"
submit(student_id, name, assignment_id, str(cost), question_id)

question_id = "q5_cost_function_gsheet"
submit(student_id, name, assignment_id, str(link_to_gsheet), question_id, drive_link)
