# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.plot(x, y);

plt.ylabel("Y Label")
plt.xlabel("X Label")
plt.title("Ini Title")

# plt.show()
# Out:
# Text(0.5, 1.0, 'Ini Title')

# %%
# Out:
# Text(0.5, 1.0, 'Ini Title')

# %%
test_arr = [1, 2]

x, y = test_arr

a = 12
b = 24

a, b = b, a

print(a)
print(b)

print(x)
print(y)
# Out:
# 24
# 12
# 1
# 2
