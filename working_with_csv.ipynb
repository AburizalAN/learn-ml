# %%
import pandas as pd

file_path = "./datasets/jobs_in_data.csv"

df = pd.read_csv(file_path, delimiter=",")

df_head = df.head(20)

# df_head["test"] = 0.5

df_head.shape

df_head.loc[:, "test"] = 2

df_head
# Out:
# C:\Users\aburi\AppData\Local\Temp\ipykernel_92132\943358613.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_head.loc[:, "test"] = 2
#     work_year                    job_title                    job_category  \
# 0        2023         Data DevOps Engineer                Data Engineering
# 1        2023               Data Architect  Data Architecture and Modeling
# 2        2023               Data Architect  Data Architecture and Modeling
# 3        2023               Data Scientist       Data Science and Research
# 4        2023               Data Scientist       Data Science and Research
# 5        2023               Data Scientist       Data Science and Research
# ...

# %%
df.groupby('work_setting')["salary"].mean()
# Out:
# work_setting
# Hybrid        91878.000000
# In-person    154834.404014
# Remote       144969.840419
# Name: salary, dtype: float64
